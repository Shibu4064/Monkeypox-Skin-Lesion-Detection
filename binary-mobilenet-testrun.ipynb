# %%
# Imports
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob as gb
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Input
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import mixed_precision
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Enable mixed precision
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()

print("Accelerators:", strategy.num_replicas_in_sync)
mixed_precision.set_global_policy('mixed_float16')

# Constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 15
SEED = 42

# Dataset directory (Kaggle path)
dataset_path = "/kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train"

# Load dataset
train_dataset = image_dataset_from_directory(
    dataset_path,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.1,
    subset='training',
    seed=SEED
)

validation_dataset = image_dataset_from_directory(
    dataset_path,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.1,
    subset='validation',
    seed=SEED
)

# Class names and distribution
class_names = train_dataset.class_names
print("Classes:", class_names)

data_imbalance = [len(gb.glob(os.path.join(dataset_path, cls, '*.*'))) for cls in class_names]
plt.figure(figsize=(10, 5))
sns.barplot(x=class_names, y=data_imbalance)
plt.title("Class Distribution")
plt.ylabel("Count")
plt.xlabel("Class")
plt.xticks(rotation=15)
plt.show()

# Class weights
total = sum(data_imbalance)
class_weight = {
    i: (1.0 / count) * (total / len(class_names))
    for i, count in enumerate(data_imbalance)
}
print("Class Weights:", class_weight)

# Data Augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomContrast(0.2),
])

AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# Build Model
def build_mobilenetv3(input_shape=(224, 224, 3), num_classes=3, fine_tune=False):
    base_model = tf.keras.applications.MobileNetV3Large(
        input_shape=input_shape,
        include_top=False,
        weights="imagenet"
    )
    base_model.trainable = fine_tune

    inputs = tf.keras.Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = tf.keras.Model(inputs, outputs)
    return model

with strategy.scope():
    model = build_mobilenetv3(input_shape=(224, 224, 3), num_classes=len(class_names))
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-4),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

model.summary()

# Callbacks
callbacks = [
    EarlyStopping(patience=3, restore_best_weights=True),
    ReduceLROnPlateau(factor=0.3, patience=2, verbose=1)
]

# Train
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    class_weight=class_weight,
    epochs=EPOCHS,
    callbacks=callbacks
)

# Plot Results
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.legend(); plt.title("Accuracy")

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.legend(); plt.title("Loss")
plt.tight_layout(); plt.show()

# Evaluation
y_true, y_pred = [], []
for images, labels in validation_dataset:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names).plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accelerators: 1
# Found 2142 files belonging to 2 classes.
# Using 1928 files for training.
# I0000 00:00:1745513066.997447      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 2142 files belonging to 2 classes.
# Using 214 files for validation.
# Classes: ['Monkeypox', 'Others']
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# Class Weights: {0: 1.092857142857143, 1: 0.9216867469879518}
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ MobileNetV3Large (Functional)        │ (None, 7, 7, 960)           │       2,996,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 960)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 960)                 │           3,840 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 960)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ cast_1 (Cast)                        │ (None, 960)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 2)                   │           1,922 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,002,114 (11.45 MB)
#  Trainable params: 3,842 (15.01 KB)
#  Non-trainable params: 2,998,272 (11.44 MB)
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745513094.960798     104 service.cc:148] XLA service 0x7f0bac0023c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745513094.961649     104 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745513096.151333     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/61 ━━━━━━━━━━━━━━━━━━━━ 31:00 31s/step - accuracy: 0.6250 - loss: 1.1248
# I0000 00:00:1745513101.958687     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 47s 269ms/step - accuracy: 0.5078 - loss: 1.1253 - val_accuracy: 0.6028 - val_loss: 0.7064 - learning_rate: 1.0000e-04
# Epoch 2/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6019 - loss: 0.8798 - val_accuracy: 0.6308 - val_loss: 0.6665 - learning_rate: 1.0000e-04
# Epoch 3/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6279 - loss: 0.7881 - val_accuracy: 0.6822 - val_loss: 0.6347 - learning_rate: 1.0000e-04
# Epoch 4/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6436 - loss: 0.7482 - val_accuracy: 0.6822 - val_loss: 0.6127 - learning_rate: 1.0000e-04
# Epoch 5/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6899 - loss: 0.6905 - val_accuracy: 0.7009 - val_loss: 0.5952 - learning_rate: 1.0000e-04
# Epoch 6/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6897 - loss: 0.6657 - val_accuracy: 0.7150 - val_loss: 0.5794 - learning_rate: 1.0000e-04
# Epoch 7/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7101 - loss: 0.6206 - val_accuracy: 0.7477 - val_loss: 0.5590 - learning_rate: 1.0000e-04
# Epoch 8/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7362 - loss: 0.5796 - val_accuracy: 0.7570 - val_loss: 0.5435 - learning_rate: 1.0000e-04
# Epoch 9/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7237 - loss: 0.5775 - val_accuracy: 0.7710 - val_loss: 0.5259 - learning_rate: 1.0000e-04
# Epoch 10/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7629 - loss: 0.5281 - val_accuracy: 0.7804 - val_loss: 0.5107 - learning_rate: 1.0000e-04
# Epoch 11/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7304 - loss: 0.5502 - val_accuracy: 0.7850 - val_loss: 0.4952 - learning_rate: 1.0000e-04
# Epoch 12/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7605 - loss: 0.5096 - val_accuracy: 0.7991 - val_loss: 0.4837 - learning_rate: 1.0000e-04
# Epoch 13/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7789 - loss: 0.4973 - val_accuracy: 0.8037 - val_loss: 0.4714 - learning_rate: 1.0000e-04
# Epoch 14/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7752 - loss: 0.4783 - val_accuracy: 0.8037 - val_loss: 0.4618 - learning_rate: 1.0000e-04
# Epoch 15/15
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7688 - loss: 0.4936 - val_accuracy: 0.8084 - val_loss: 0.4540 - learning_rate: 1.0000e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    Monkeypox       0.75      0.72      0.74        80
#       Others       0.84      0.86      0.85       134
#
#     accuracy                           0.81       214
#    macro avg       0.80      0.79      0.79       214
# weighted avg       0.81      0.81      0.81       214
