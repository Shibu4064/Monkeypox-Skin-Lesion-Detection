# %%
# 📦 Imports
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob as gb
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras import mixed_precision

# ⚡ Enable mixed precision
mixed_precision.set_global_policy('mixed_float16')

# ⚙️ Config
IMG_SIZE = (299, 299)
BATCH_SIZE = 32
EPOCHS = 20
SEED = 42
DATA_DIR = "/kaggle/input/mpox-skin-lesion-dataset-version-20-msld-v20/Augmented Images/Augmented Images/FOLDS_AUG/fold3_AUG/Train"

# 📂 Load Datasets
train_dataset = image_dataset_from_directory(
    DATA_DIR,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.1,
    subset='training',
    seed=SEED
)

validation_dataset = image_dataset_from_directory(
    DATA_DIR,
    shuffle=True,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.1,
    subset='validation',
    seed=SEED
)

class_names = train_dataset.class_names
print("Classes:", class_names)

# 📊 Visualize Class Distribution
data_imbalance = []
for class_folder in class_names:
    file_list = gb.glob(os.path.join(DATA_DIR, class_folder, '*.*'))
    data_imbalance.append(len(file_list))

plt.figure(figsize=(13, 6))
sns.barplot(x=class_names, y=data_imbalance, palette="rocket")
plt.title("Class Distribution")
plt.ylabel("Number of Images")
plt.xticks(rotation=15)
plt.show()

# 📈 Compute Class Weights
total_images = sum(data_imbalance)
class_weight = {i: (1.0 / count) * (total_images / len(data_imbalance)) for i, count in enumerate(data_imbalance)}
print("\nClass Weights:")
for i, w in class_weight.items():
    print(f"{class_names[i]}: {w:.2f}")

# 🔥 Data Augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.15),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
])

AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)

# 🏗️ Build InceptionV3 Model
def build_inceptionv3(input_shape=(299, 299, 3), num_classes=6):
    base_model = InceptionV3(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = False  # Freeze base initially

    inputs = Input(shape=input_shape)
    x = tf.keras.applications.inception_v3.preprocess_input(inputs)
    x = base_model(x, training=False)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = Model(inputs, outputs)
    return model, base_model

model, base_model = build_inceptionv3(input_shape=(299, 299, 3), num_classes=len(class_names))

model.compile(
    optimizer=AdamW(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# ⏰ Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1),
    ModelCheckpoint("best_inceptionv3_model.keras", monitor="val_loss", save_best_only=True, verbose=1)
]

# 🏃‍♂️ 1st Phase: Train feature extractor
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    class_weight=class_weight,
    epochs=EPOCHS,
    callbacks=callbacks
)

# 🔥 Fine-tune Top Layers
print("\nUnfreezing top 50 layers for fine-tuning...")
base_model.trainable = True

# Freeze all layers except the last 50
for layer in base_model.layers[:-50]:
    layer.trainable = False

# Re-compile with a lower learning rate
model.compile(
    optimizer=AdamW(learning_rate=1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 🏃‍♂️ 2nd Phase: Fine-tuning
fine_tune_epochs = 10
total_epochs = EPOCHS + fine_tune_epochs

history_finetune = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    class_weight=class_weight,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1]+1,
    callbacks=callbacks
)

# 📈 Combine and Plot Metrics
acc = history.history['accuracy'] + history_finetune.history['accuracy']
val_acc = history.history['val_accuracy'] + history_finetune.history['val_accuracy']
loss = history.history['loss'] + history_finetune.history['loss']
val_loss = history.history['val_loss'] + history_finetune.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.axvline(x=history.epoch[-1], color='gray', linestyle='--', label='Fine-tuning Start')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.axvline(x=history.epoch[-1], color='gray', linestyle='--')
plt.title('Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# 🧪 Evaluate
true_labels = []
predicted_labels = []

for images, labels in validation_dataset:
    predictions = model(images, training=False)
    predicted_classes = tf.argmax(predictions, axis=1).numpy()
    true_labels.extend(labels.numpy())
    predicted_labels.extend(predicted_classes)

# 📋 Classification Report
print("\nClassification Report:\n")
print(classification_report(true_labels, predicted_labels, target_names=class_names))

# 🔥 Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(8,8))
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2025-04-26 18:46:08.282927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745693168.503187      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745693168.569553      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 7532 files belonging to 6 classes.
# Using 6779 files for training.
# I0000 00:00:1745693191.616027      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 7532 files belonging to 6 classes.
# Using 753 files for validation.
# Classes: ['Chickenpox', 'Cowpox', 'HFMD', 'Healthy', 'Measles', 'Monkeypox']
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# Class Weights:
# Chickenpox: 1.76
# Cowpox: 1.91
# HFMD: 0.79
# Healthy: 1.20
# Measles: 2.49
# Monkeypox: 0.42
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 299, 299, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ true_divide (TrueDivide)             │ (None, 299, 299, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ subtract (Subtract)                  │ (None, 299, 299, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_v3 (Functional)            │ (None, 8, 8, 2048)          │      21,802,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_94               │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ cast_1 (Cast)                        │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 6)                   │          12,294 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,823,270 (83.25 MB)
#  Trainable params: 16,390 (64.02 KB)
#  Non-trainable params: 21,806,880 (83.19 MB)
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745693215.467582     100 service.cc:148] XLA service 0x78bf4c004a50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745693215.468502     100 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745693218.677463     100 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/212 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.1797 - loss: 3.0324
# I0000 00:00:1745693228.368374     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.2442 - loss: 2.5353
# Epoch 1: val_loss improved from inf to 1.33791, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 131s 489ms/step - accuracy: 0.2444 - loss: 2.5339 - val_accuracy: 0.5060 - val_loss: 1.3379 - learning_rate: 1.0000e-04
# Epoch 2/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.4543 - loss: 1.5150
# Epoch 2: val_loss improved from 1.33791 to 1.19435, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 80s 370ms/step - accuracy: 0.4544 - loss: 1.5147 - val_accuracy: 0.5870 - val_loss: 1.1944 - learning_rate: 1.0000e-04
# Epoch 3/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.5269 - loss: 1.2609
# Epoch 3: val_loss improved from 1.19435 to 1.10060, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 367ms/step - accuracy: 0.5270 - loss: 1.2607 - val_accuracy: 0.6375 - val_loss: 1.1006 - learning_rate: 1.0000e-04
# Epoch 4/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.5696 - loss: 1.0900
# Epoch 4: val_loss improved from 1.10060 to 1.01255, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 368ms/step - accuracy: 0.5697 - loss: 1.0900 - val_accuracy: 0.6653 - val_loss: 1.0126 - learning_rate: 1.0000e-04
# Epoch 5/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.6125 - loss: 1.0069
# Epoch 5: val_loss improved from 1.01255 to 0.95579, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 78s 364ms/step - accuracy: 0.6125 - loss: 1.0068 - val_accuracy: 0.6906 - val_loss: 0.9558 - learning_rate: 1.0000e-04
# Epoch 6/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.6304 - loss: 0.9308
# Epoch 6: val_loss improved from 0.95579 to 0.89524, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 80s 372ms/step - accuracy: 0.6304 - loss: 0.9307 - val_accuracy: 0.7039 - val_loss: 0.8952 - learning_rate: 1.0000e-04
# Epoch 7/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.6511 - loss: 0.9056
# Epoch 7: val_loss improved from 0.89524 to 0.85290, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 80s 371ms/step - accuracy: 0.6511 - loss: 0.9054 - val_accuracy: 0.7025 - val_loss: 0.8529 - learning_rate: 1.0000e-04
# Epoch 8/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.6744 - loss: 0.8080
# Epoch 8: val_loss improved from 0.85290 to 0.81882, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 368ms/step - accuracy: 0.6744 - loss: 0.8080 - val_accuracy: 0.7185 - val_loss: 0.8188 - learning_rate: 1.0000e-04
# Epoch 9/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.6795 - loss: 0.8059
# Epoch 9: val_loss improved from 0.81882 to 0.79147, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 369ms/step - accuracy: 0.6795 - loss: 0.8058 - val_accuracy: 0.7344 - val_loss: 0.7915 - learning_rate: 1.0000e-04
# Epoch 10/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.6891 - loss: 0.7566
# Epoch 10: val_loss improved from 0.79147 to 0.75547, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 81s 365ms/step - accuracy: 0.6892 - loss: 0.7566 - val_accuracy: 0.7397 - val_loss: 0.7555 - learning_rate: 1.0000e-04
# Epoch 11/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.6902 - loss: 0.7605
# Epoch 11: val_loss improved from 0.75547 to 0.74140, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 368ms/step - accuracy: 0.6902 - loss: 0.7604 - val_accuracy: 0.7410 - val_loss: 0.7414 - learning_rate: 1.0000e-04
# Epoch 12/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7151 - loss: 0.6839
# Epoch 12: val_loss improved from 0.74140 to 0.70869, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 367ms/step - accuracy: 0.7151 - loss: 0.6839 - val_accuracy: 0.7503 - val_loss: 0.7087 - learning_rate: 1.0000e-04
# Epoch 13/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.7200 - loss: 0.6709
# Epoch 13: val_loss improved from 0.70869 to 0.69852, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 366ms/step - accuracy: 0.7200 - loss: 0.6708 - val_accuracy: 0.7530 - val_loss: 0.6985 - learning_rate: 1.0000e-04
# Epoch 14/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7322 - loss: 0.6381
# Epoch 14: val_loss improved from 0.69852 to 0.67892, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 82s 366ms/step - accuracy: 0.7322 - loss: 0.6382 - val_accuracy: 0.7610 - val_loss: 0.6789 - learning_rate: 1.0000e-04
# Epoch 15/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7290 - loss: 0.6541
# Epoch 15: val_loss improved from 0.67892 to 0.67530, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 366ms/step - accuracy: 0.7290 - loss: 0.6540 - val_accuracy: 0.7676 - val_loss: 0.6753 - learning_rate: 1.0000e-04
# Epoch 16/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7238 - loss: 0.6233
# Epoch 16: val_loss improved from 0.67530 to 0.65717, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 368ms/step - accuracy: 0.7238 - loss: 0.6232 - val_accuracy: 0.7663 - val_loss: 0.6572 - learning_rate: 1.0000e-04
# Epoch 17/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.7409 - loss: 0.6272
# Epoch 17: val_loss improved from 0.65717 to 0.65023, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 81s 365ms/step - accuracy: 0.7409 - loss: 0.6271 - val_accuracy: 0.7676 - val_loss: 0.6502 - learning_rate: 1.0000e-04
# Epoch 18/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7453 - loss: 0.6028
# Epoch 18: val_loss improved from 0.65023 to 0.63779, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 80s 371ms/step - accuracy: 0.7454 - loss: 0.6027 - val_accuracy: 0.7676 - val_loss: 0.6378 - learning_rate: 1.0000e-04
# Epoch 19/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7452 - loss: 0.5839
# Epoch 19: val_loss improved from 0.63779 to 0.61968, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 79s 367ms/step - accuracy: 0.7452 - loss: 0.5840 - val_accuracy: 0.7756 - val_loss: 0.6197 - learning_rate: 1.0000e-04
# Epoch 20/20
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7623 - loss: 0.5696
# Epoch 20: val_loss improved from 0.61968 to 0.59836, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 82s 370ms/step - accuracy: 0.7623 - loss: 0.5696 - val_accuracy: 0.7849 - val_loss: 0.5984 - learning_rate: 1.0000e-04
#
# Unfreezing top 50 layers for fine-tuning...
# Epoch 21/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.7159 - loss: 0.7550
# Epoch 21: val_loss did not improve from 0.59836
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 129s 447ms/step - accuracy: 0.7159 - loss: 0.7547 - val_accuracy: 0.7915 - val_loss: 0.5989 - learning_rate: 1.0000e-05
# Epoch 22/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7618 - loss: 0.5642
# Epoch 22: val_loss improved from 0.59836 to 0.54858, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 111s 371ms/step - accuracy: 0.7619 - loss: 0.5641 - val_accuracy: 0.8088 - val_loss: 0.5486 - learning_rate: 1.0000e-05
# Epoch 23/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7818 - loss: 0.4993
# Epoch 23: val_loss improved from 0.54858 to 0.51523, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 80s 372ms/step - accuracy: 0.7818 - loss: 0.4992 - val_accuracy: 0.8154 - val_loss: 0.5152 - learning_rate: 1.0000e-05
# Epoch 24/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8062 - loss: 0.4342
# Epoch 24: val_loss improved from 0.51523 to 0.47038, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 80s 373ms/step - accuracy: 0.8062 - loss: 0.4341 - val_accuracy: 0.8367 - val_loss: 0.4704 - learning_rate: 1.0000e-05
# Epoch 25/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8144 - loss: 0.3879
# Epoch 25: val_loss improved from 0.47038 to 0.45599, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 82s 372ms/step - accuracy: 0.8144 - loss: 0.3879 - val_accuracy: 0.8420 - val_loss: 0.4560 - learning_rate: 1.0000e-05
# Epoch 26/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.8330 - loss: 0.3527
# Epoch 26: val_loss improved from 0.45599 to 0.43162, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 81s 378ms/step - accuracy: 0.8330 - loss: 0.3527 - val_accuracy: 0.8446 - val_loss: 0.4316 - learning_rate: 1.0000e-05
# Epoch 27/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8353 - loss: 0.3274
# Epoch 27: val_loss improved from 0.43162 to 0.39287, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 82s 382ms/step - accuracy: 0.8353 - loss: 0.3274 - val_accuracy: 0.8513 - val_loss: 0.3929 - learning_rate: 1.0000e-05
# Epoch 28/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8540 - loss: 0.3042
# Epoch 28: val_loss improved from 0.39287 to 0.35911, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 80s 373ms/step - accuracy: 0.8540 - loss: 0.3041 - val_accuracy: 0.8685 - val_loss: 0.3591 - learning_rate: 1.0000e-05
# Epoch 29/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.8668 - loss: 0.2655
# Epoch 29: val_loss improved from 0.35911 to 0.33078, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 81s 377ms/step - accuracy: 0.8668 - loss: 0.2655 - val_accuracy: 0.8778 - val_loss: 0.3308 - learning_rate: 1.0000e-05
# Epoch 30/30
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8696 - loss: 0.2658
# Epoch 30: val_loss improved from 0.33078 to 0.31409, saving model to best_inceptionv3_model.keras
# 212/212 ━━━━━━━━━━━━━━━━━━━━ 81s 375ms/step - accuracy: 0.8697 - loss: 0.2657 - val_accuracy: 0.8884 - val_loss: 0.3141 - learning_rate: 1.0000e-05
# Classification Report:
#
#               precision    recall  f1-score   support
#
#   Chickenpox       0.70      0.92      0.79        61
#       Cowpox       0.74      0.99      0.84        68
#         HFMD       0.89      0.97      0.93       154
#      Healthy       0.90      0.98      0.94       116
#      Measles       0.93      0.91      0.92        45
#    Monkeypox       0.99      0.78      0.88       309
#
#     accuracy                           0.89       753
#    macro avg       0.86      0.92      0.88       753
# weighted avg       0.91      0.89      0.89       753
